# %%
import pandas as pd
import xml.etree.ElementTree as et
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# Run this cell to mount your Google Drive.
from google.colab import drive
drive.mount('/content/drive')
base_dir2='/content/drive/My Drive/GoogleDrive20180110/DoutoradoUSP/CONITEC'
os.chdir(base_dir2)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1.1 - Importing Web Of Knowledge papers

# %%
wos = pd.read_html('webofscience_PDT_01.html')#, sep=";",error_bad_lines=False)
print(len(wos))
AB=[] # Abstract
PM=[] # PUBMED ID
PY=[] # Year Published
SC=[] # Research Area
KW=[] # Paper Keywords
PT=[] # Publication Type - Journal;Book;Series;Patent
TI=[] # Document Title
DI=[] # DOI
for ii in range(len(wos)):
  aux2=np.where(wos[ii][0]=="AB")
  if len(aux2[0])==0:
    AB.append('None')
  else:
    idx=aux2[0][0]
    AB.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="PM")
  if len(aux2[0])==0:
    PM.append('None')
  else:
    idx=aux2[0][0]
    PM.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="PY")
  if len(aux2[0])==0:
    PY.append('None')
  else:
    idx=aux2[0][0]
    PY.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="SC")
  if len(aux2[0])==0:
    SC.append('None')
  else:
    idx=aux2[0][0]
    SC.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="DE")
  if len(aux2[0])==0:
    KW.append('None')
  else:
    idx=aux2[0][0]
    KW.append(wos[ii][1][idx])    
  aux2=np.where(wos[ii][0]=="PT")
  if len(aux2[0])==0:
    PT.append('None')
  else:
    idx=aux2[0][0]
    PT.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="TI")
  if len(aux2[0])==0:
    TI.append('None')
  else:
    idx=aux2[0][0]
    TI.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="DI")
  if len(aux2[0])==0:
    DI.append('None')
  else:
    idx=aux2[0][0]
    DI.append(wos[ii][1][idx])

df_wos1=pd.DataFrame(PM)
df_wos1.columns=['pmid']
df_wos1['doi_wos']=DI
df_wos1['title_wos']=TI
df_wos1['abstract_wos']=AB
df_wos1['publication_year']=PY
df_wos1['research_area']=SC
df_wos1['keywords']=KW
df_wos1['publication_type']=PT
df_wos1 = df_wos1.drop(df_wos1[df_wos1.title_wos=='None'].iloc[:].index)
# Out:
# 855

# %%
wos = pd.read_html('webofscience_PDT_02.html')#, sep=";",error_bad_lines=False)
print(len(wos))
AB=[] # Abstract
PM=[] # PUBMED ID
PY=[] # Year Published
SC=[] # Research Area
KW=[] # Paper Keywords
PT=[] # Publication Type - Journal;Book;Series;Patent
TI=[] # Document Title
DI=[] # DOI
for ii in range(len(wos)):
  aux2=np.where(wos[ii][0]=="AB")
  if len(aux2[0])==0:
    AB.append('None')
  else:
    idx=aux2[0][0]
    AB.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="PM")
  if len(aux2[0])==0:
    PM.append('None')
  else:
    idx=aux2[0][0]
    PM.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="PY")
  if len(aux2[0])==0:
    PY.append('None')
  else:
    idx=aux2[0][0]
    PY.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="SC")
  if len(aux2[0])==0:
    SC.append('None')
  else:
    idx=aux2[0][0]
    SC.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="DE")
  if len(aux2[0])==0:
    KW.append('None')
  else:
    idx=aux2[0][0]
    KW.append(wos[ii][1][idx])    
  aux2=np.where(wos[ii][0]=="PT")
  if len(aux2[0])==0:
    PT.append('None')
  else:
    idx=aux2[0][0]
    PT.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="TI")
  if len(aux2[0])==0:
    TI.append('None')
  else:
    idx=aux2[0][0]
    TI.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="DI")
  if len(aux2[0])==0:
    DI.append('None')
  else:
    idx=aux2[0][0]
    DI.append(wos[ii][1][idx])

df_wos2=pd.DataFrame(PM)
df_wos2.columns=['pmid']
df_wos2['doi_wos']=DI
df_wos2['title_wos']=TI
df_wos2['abstract_wos']=AB
df_wos2['publication_year']=PY
df_wos2['research_area']=SC
df_wos2['keywords']=KW
df_wos2['publication_type']=PT
df_wos2 = df_wos2.drop(df_wos2[df_wos2.title_wos=='None'].iloc[:].index)
# Out:
# 878

# %%
wos = pd.read_html('webofscience_PDT_03.html')#, sep=";",error_bad_lines=False)
print(len(wos))
AB=[] # Abstract
PM=[] # PUBMED ID
PY=[] # Year Published
SC=[] # Research Area
KW=[] # Paper Keywords
PT=[] # Publication Type - Journal;Book;Series;Patent
TI=[] # Document Title
DI=[] # DOI
for ii in range(len(wos)):
  aux2=np.where(wos[ii][0]=="AB")
  if len(aux2[0])==0:
    AB.append('None')
  else:
    idx=aux2[0][0]
    AB.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="PM")
  if len(aux2[0])==0:
    PM.append('None')
  else:
    idx=aux2[0][0]
    PM.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="PY")
  if len(aux2[0])==0:
    PY.append('None')
  else:
    idx=aux2[0][0]
    PY.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="SC")
  if len(aux2[0])==0:
    SC.append('None')
  else:
    idx=aux2[0][0]
    SC.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="DE")
  if len(aux2[0])==0:
    KW.append('None')
  else:
    idx=aux2[0][0]
    KW.append(wos[ii][1][idx])    
  aux2=np.where(wos[ii][0]=="PT")
  if len(aux2[0])==0:
    PT.append('None')
  else:
    idx=aux2[0][0]
    PT.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="TI")
  if len(aux2[0])==0:
    TI.append('None')
  else:
    idx=aux2[0][0]
    TI.append(wos[ii][1][idx])
  aux2=np.where(wos[ii][0]=="DI")
  if len(aux2[0])==0:
    DI.append('None')
  else:
    idx=aux2[0][0]
    DI.append(wos[ii][1][idx])
    
    
df_wos3=pd.DataFrame(PM)
df_wos3.columns=['pmid']
df_wos3['doi_wos']=DI
df_wos3['title_wos']=TI
df_wos3['abstract_wos']=AB
df_wos3['publication_year']=PY
df_wos3['research_area']=SC
df_wos3['keywords']=KW
df_wos3['publication_type']=PT
df_wos3 = df_wos3.drop(df_wos3[df_wos3.title_wos=='None'].iloc[:].index)
# Out:
# 420

# %%
df_wos=pd.concat([df_wos1,df_wos2,df_wos3],ignore_index=True)
del df_wos1, df_wos2, df_wos3
df_wos.head()
# Out:
#        pmid  ... publication_type
# 0  31500949  ...                J
# 1  31543301  ...                J
# 2  31355928  ...                J
# 3  31466584  ...                J
# 4  31555659  ...                J
#
# [5 rows x 8 columns]

# %% [markdown]
# # 1.2 - Importing and mounting dataframe from pubmed XML

# %%
pubmedXML=et.parse('pubmed_result_PDT_Total_semfiltro.xml')
len(pubmedXML.getroot())
print('IMPORTANDO PUBMED TOTAL PDT')
# Out:
# 26346

# %%
# ii=2
# # a3=pubmedXML.getroot()[ii][0][3].find('AuthorList')
# # print(len(a3.getchildren()))
# # print('***')
# # author=a3.getchildren()
# # print(author)
# # print('***')
# # jj=2
# # #info=author[jj]
# # info=author[jj].find('AffiliationInfo')

# a3=pubmedXML.getroot()[ii][0][3].findall('ELocationID')
# idx=a3[0]
# print(idx)
# #DOI=a3.getchildren()
# #print(DOI)

# %%
DOI=[]
count=0
count2=0
count3=0
for ii in range(len(pubmedXML.getroot())):
  a3=pubmedXML.getroot()[ii][0][3].findall('ELocationID')
  if len(a3)==0:
#    print('***AuthorList***')
#    print(ii)
#    print('None')
    count=count+1
    #department.text=None
    DOI.append('None')
  else:
    for jj in range(len(a3)):
      info=a3[jj]
      if info.items()[0][1]=='doi':
        DOI.append(info.text)
        break
      elif info.items()[0][1]=='pii':
        count2=count2+1
        DOI.append('None')
        break
#       elif info.items()[0][1]=='pubmed':
#         count3=count3+1
#         DOI.append('None')
#         break
print('Count of papers without ELocationID:',count)
print('Count of papers without DOI with pii:',count2)
# print('Count of papers without DOI with pubmed:',count3)
print(len(DOI))
# Out:
# Count of papers without ELocationID: 14244
# Count of papers without DOI with pii: 1451
# 26346

# %%
pmid=[]
count=0
for ii in range(len(pubmedXML.getroot())):
  a3=pubmedXML.getroot()[ii][0][0]
  if a3 ==None:
    pmid.append('None')
  else:
    pmid.append(a3.text)

# %%
Title=[]
count=0
for ii in range(len(pubmedXML.getroot())):
  a3=pubmedXML.getroot()[ii][0][3].find('ArticleTitle')
  if a3 ==None:
    Title.append('None')
  else:
    Title.append(a3.text)

# %%
Abs=[]
count=0
for ii in range(len(pubmedXML.getroot())):
  a3=pubmedXML.getroot()[ii][0][3].find('Abstract')
  if a3 ==None:
    Abs.append('None')
  else:
    text=''
    for jj in range(len(a3.getchildren())):
      abstract=a3.getchildren()
      if abstract==None:
        Abs.append('None')
      else:
        if abstract[jj].text==None:
          text='None'
        else:
          text=text+abstract[jj].text
    Abs.append(text)

# %%
abstract[0].text

# %%
Af_L=[]
count=0
count2=0
count3=0
for ii in range(len(pubmedXML.getroot())):
  a3=pubmedXML.getroot()[ii][0][3].find('AuthorList')
  if a3==None:
#    print('***AuthorList***')
#    print(ii)
#    print('None')
    count=count+1
    #department.text=None
    Af_L.append('None')
  else:
    for jj in range(len(a3.getchildren())):
      author=a3.getchildren()
#PAREI AQUI
      if author==None:
#      print('***Author***')
#      print(ii)
#      print('None')
        count2=count2+1
        Af_L.append('None')
      else:
        info=author[jj].find('AffiliationInfo')
        if info==None:
#        print('***Author***')
#        print(ii)
#        print('None')
          count3=count3+1
          Af_L.append('None')
        else:
          department=info.find('Affiliation')
          Af_L.append(department.text)
print('Count of papers without authors:',count)
print('Count of papers without author affiliation infos:',count2)
print('Count of papers without author real affiliation:',count3)
# Out:
# Count of papers without authors: 2183
# Count of papers without author affiliation infos: 0
# Count of papers without author real affiliation: 70578

# %%
df_Af_L=pd.DataFrame(Af_L)
df_Af_L.columns=['Author_Affiliation']
#df_Af_L.sample(10)
df_Af_L.shape
# Out:
# (123177, 1)

# %%
df_pubmed=pd.DataFrame(Title)
df_pubmed.columns=['title_pubmed']
df_pubmed['abstract_pubmed']=Abs
df_pubmed['pmid']=pmid
df_pubmed['doi_pubmed']=DOI
df_pubmed=df_pubmed.drop(df_pubmed[df_pubmed.title_pubmed=='None'].iloc[:].index)
df_pubmed=df_pubmed.reset_index()
df_pubmed=df_pubmed.drop('index',axis=1)
df_pubmed.head()
# Out:
#                                         title_pubmed  ...                   doi_pubmed
# 0  Excited State Torsional Processes in Chalcogen...  ...     10.1021/acs.jpca.9b07268
# 1  New strategies and developments for peri-impla...  ...                         None
# 2  Comparison of apical periodontitis repair in e...  ...                         None
# 3  Antimicrobial photodynamic therapy on teeth wi...  ...  10.1097/MD.0000000000017355
# 4  Evaluation of halitosis in adult patients afte...  ...  10.1097/MD.0000000000016976
#
# [5 rows x 4 columns]

# %%
df_Af_L = df_Af_L.drop(df_Af_L[df_Af_L.Author_Affiliation=='None'].iloc[:].index)
#df_Af_L.replace(to_replace='None', value=np.nan)
#df_Af_L.dropna()
print(df_Af_L.shape)
print(df_Af_L.sample(10))
# Out:
# (50416, 1)
#                                       Author_Affiliation
# 56002  GEPLO-Group of Study and Research of Lasers in...
# 27724  Institute of Functional Nano & Soft Materials ...
# 11491  State Key Laboratory of Luminescence and Appli...
# 28631  Department of Endodontics, Faculty of Dentistr...
# 19366  School of Chemistry and Chemical Engineering, ...
# 8410   Department of Biomedical Engineering, College ...
# 93913  Division of Respiratory Medicine, University o...
# 83801  Regional Medical Physics Department, Newcastle...
# 4524   State Key Laboratory of Molecular Engineering ...
# 40162  Biofilm Research Cluster and Department of Con...

# %% [markdown]
# # 1.3 - Join Pubmed and WebofScience Dataframes

# %%
join=0

# %%
if join:
  print('Number of WebOfKnowledge papers:',df_wos.shape)
  print('Number of PubMed papers:',df_pubmed.shape)
  df_pubmed2=df_pubmed
# Out:
# Number of WebOfKnowledge papers: (1274, 9)
# Number of PubMed papers: (680, 5)

# %%
if join:
  result=pd.merge(df_pubmed,
                 df_wos,
                 left_on='pmid',
                 right_on='pmid',
                 how='outer')
  #df_pubmed2.join(df_wos.set_index('pmid'),on='pmid')
  print('Number of total papers:',result.shape)
  result.sample(10)
# Out:
# Number of total papers: (1452, 13)

# %% [markdown]
# ---
# If ABSTRACT = NAN and None => drop paper
#
# else if NOne use abstract_pubmed
#
# else if NAN use abstract_wos
#
#
#
# ---
#
#
#
# If TITLE = NAN and None => drop paper
#
# else if NOne use title_pubmed
#
# else if NAN use title_wos
#
#
# ---

# %%
if join:
  print('doi_wos:',np.where(pd.isnull(result.doi_wos))[0][:])

  #print('doi_pubmed',np.where(pd.isnull(result.doi_pubmed))[0][:])
# Out:
# doi_wos: [  0   1  13  14  24  36  42  52  61  75  77  86  90 101 110 113 115 122
#  125 126 136 140 147 150 153 155 166 167 168 169 170 172 176 179 191 193
#  194 197 206 213 220 222 224 225 227 234 241 242 244 245 249 250 252 258
#  268 270 271 272 278 287 304 307 309 310 314 320 322 326 330 334 339 346
#  355 359 370 374 383 385 395 401 406 411 419 424 425 427 434 435 439 448
#  449 450 454 466 469 473 483 486 493 497 506 507 508 509 515 516 522 525
#  531 538 539 551 555 565 578 582 586 587 595 602 604 605 609 610 611 614
#  619 620 621 623 625 626 627 631 632 633 637 638 639 640 642 643 644 645
#  646 647 648 649 650 651 652 653 654 655 656 657 658 659 660 661 662 663
#  664 665 666 667 668 669 670 671 672 673 674 675 676 677 678 679]

# %%
result.iloc[237]
# Out:
# title_pubmed        High and sustained efficacy after two sessions...
# abstract_pubmed     Prolonged follow-up data on topical photodynam...
# pmid                                                         22309486
# doi_pubmed                           10.1111/j.1365-2133.2012.10878.x
# clean_abstract_x    prolong follow up data on topic photodynam the...
# doi_wos                              10.1111/j.1365-2133.2012.10878.x
# title_wos           High and sustained efficacy after two sessions...
# abstract_wos                                                     None
# publication_year                                                 2012
# research_area                                             Dermatology
# keywords                                                         None
# publication_type                                                    J
# clean_abstract_y                                                 none
# Name: 237, dtype: object

# %%
if join:
  idx=np.where(pd.isnull(result.doi_wos))[0][:]
  #print(idx)
  result['final_doi']=result.doi_wos
  for ii in range(len(idx)):
    result.final_doi[idx[ii]]=result.doi_pubmed[idx[ii]]


  idx=np.where(pd.isnull(result.title_wos))[0][:]
  #print(idx)
  result['final_title']=result.title_wos
  for ii in range(len(idx)):
    result.final_title[idx[ii]]=result.title_pubmed[idx[ii]]


  idx=np.where(pd.isnull(result.abstract_pubmed))[0][:]
  #print(idx)
  result['final_abstract']=result.abstract_pubmed
  for ii in range(len(idx)):
    result.final_abstract[idx[ii]]=result.abstract_wos[idx[ii]]

#   result = result.drop(result[result.final_abstract=='None'].iloc[:].index)

# %%
if join:
  print('Without doi_final:',np.where(result.final_doi=='None')[0][:])
# Out:
# Without doi_final: [   0    1   13   24   42   52   80   96   98  101  103  129  141  147
#   154  155  158  172  177  179  188  201  204  220  246  250  274  284
#   287  289  301  302  303  304  307  313  315  317  326  329  339  344
#   355  358  359  372  376  378  383  385  392  395  401  406  407  411
#   419  424  425  426  427  434  435  439  448  449  450  451  454  466
#   469  473  480  483  486  493  497  506  507  508  509  515  516  519
#   522  525  526  528  529  531  538  539  540  551  553  555  556  558
#   559  560  562  564  565  566  567  569  572  573  577  578  579  580
#   582  586  587  595  599  601  602  604  605  609  610  611  612  613
#   614  618  619  620  621  622  623  625  626  627  631  632  633  637
#   638  639  640  641  642  643  644  645  646  647  648  649  650  651
#   652  653  654  655  656  657  658  659  660  661  662  663  664  665
#   666  667  668  669  670  671  672  673  674  675  676  677  678  679
#   692  695  701  704  705  707  708  710  715  717  718  719  720  722
#   724  730  731  732  735  740  741  743  744  745  746  750  755  756
#   765  766  767  768  769  774  775  779  780  782  783  784  785  787
#   788  789  790  801  804  805  806  810  812  814  815  818  819  820
#   822  823  828  829  830  831  832  834  839  840  842  843  844  848
#   849  850  851  852  853  855  856  860  874  876  877  878  879  880
#   881  882  883  884  913  936  952  981  982  985 1033 1107 1188 1193
#  1203 1204 1222 1223 1226 1233 1234 1238 1259 1271 1278 1297 1325 1332
#  1394 1397 1401 1402 1406 1412 1413 1418 1419 1424 1426 1428 1429 1430
#  1431 1434 1435 1444 1448]

# %%
if join:
  result.head()

# %% [markdown]
# # 1.4 - Preparing functions

# %%
import re
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import text_to_word_sequence
import nltk
nltk.download("stopwords")
nltk.download("punkt")
from nltk.corpus import stopwords
max_features=5000
max_sequence_length=500

def clean_str(string):
    string = re.sub(r"\'s", " \'s", string)
    string = re.sub(r"\'ve", " \'ve", string)
    string = re.sub(r"n\'t", " n\'t", string)
    string = re.sub(r"\'re", " \'re", string)
    string = re.sub(r"\'d", " \'d", string)
    string = re.sub(r"\'ll", " \'ll", string)
    string = re.sub(r",", " , ", string)
    string = re.sub(r"!", " ! ", string)
    string = re.sub(r"\(", " \( ", string)
    string = re.sub(r"\)", " \) ", string)
    string = re.sub(r"\?", " \? ", string)
    string = re.sub(r"\s{2,}", " ", string)

    cleanr = re.compile('<.*?>')

    string = re.sub(r'\d+', '', string)
    string = re.sub(cleanr, '', string)
    string = re.sub("'", '', string)
    string = re.sub(r'\W+', ' ', string)
    string = string.replace('_', '')


    return string.strip().lower()



def prepare_data(data):
    # data= pandas.DataFrame = df neste caso
    df_Af_L['clean_Affiliation'] = df_Af_L['Author_Affiliation'].apply(lambda x: clean_str(x))

    
    stop_words = set(stopwords.words('english'))
    text = []
    for row in df_Af_L['clean_Affiliation'].values:
        word_list = text_to_word_sequence(row)
        no_stop_words = [w for w in word_list if not w in stop_words]
        no_stop_words = " ".join(no_stop_words)
        text.append(no_stop_words)


    tk = Tokenizer(num_words=max_features, split=' ')

    tk.fit_on_texts(text)
    X = tk.texts_to_sequences(text)  
    
    X = pad_sequences(X, maxlen=max_sequence_length)
    #X = pad_sequences(X)

    word_index = tk.word_index
#    Y = pd.get_dummies(data['KeyWords']).values
#    X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.20, random_state = 1000)

#    return X_train, X_test, Y_train, Y_test, word_index, tk , text
    return X, word_index, tk , text
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # 2.1 Affiliation Info Counting part

# %%
X, word_index, tk, sentences = prepare_data(df_Af_L)

# %%
# summarize what was learned
print('Word Counts:\n',tk.word_counts)
print('\n Document Counts:\n',tk.document_count)
print('\n Word Index:\n',tk.word_index)
print('\nWord Docs:\n',tk.word_docs)

vocab_size = len(tk.word_counts)+1
print('\n Vocabulary Size:\n',vocab_size)
# Out:
# Word Counts:
#  OrderedDict([('department', 25868), ('chemistry', 6623), ('university', 34715), ('rochester', 318), ('new', 1965), ('york', 1324), ('united', 1399), ('states', 951), ('buffalo', 660), ('state', 3357), ('universidade', 1105), ('de', 8420), ('são', 2784), ('paulo', 2190), ('usp', 341), ('school', 10289), ('dentistry', 2359), ('ribeirao', 63), ('preto', 528), ('bucco', 21), ('maxillo', 38), ('facial', 48), ('surgery', 3167), ('traumatology', 42), ('periodontology', 360), ('ribeirão', 433), ('sp', 1183), ('brazil', 3212), ('private', 73), ('practice', 89), ('unaerp', 1), ('pediatric', 185), ('faculdade', 215), ('amazonas', 10), ('iaes', 2), ('amazonian', 2), ('institute', 10296), ('higher', 48), ('education', 1381), ('manaus', 7), ('faciplac', 2), ('brasília', 143), ('df', 70), ('orthodontics', 58), ('federal', 903), ('minas', 165), ('gerais', 165), ('belo', 94), ('horizonte', 94), ('mg', 211), ('biophotonics', 449), ('applied', 905), ('health', 2439), ('sciences', 7793), ('nove', 246), ('julho', 246), ('uniceplac', 1), ('julio', 2), ('mesquita', 12), ('filho', 29), ('araraquara', 379), ('postgraduate', 228), ('program', 507), ('uninove', 155), ('microbiology', 562), ('biomedical', 2388), ('assistant', 9), ('professor', 95), ('specialization', 1), ('oral', 775), ('maxillofacial', 266), ('fundecto', 1), ('ffo', 1), ('fousp', 2), ('nano', 791), ('science', 5670), ('ewha', 69), ('womans', 59), ('seoul', 1020), ('korea', 2271), ('jyoon', 7), ('ac', 1577), ('kr', 235), ('college', 5131), ('chemical', 2155), ('engineering', 5329), ('materials', 2976), ('collaborative', 507), ('innovation', 792), ('center', 7734), ('functionalized', 53), ('probes', 132), ('imaging', 872), ('universities', 60), ('shandong', 441), ('key', 6033), ('laboratory', 7960), ('molecular', 2450), ('ministry', 1224), ('provincial', 257), ('clean', 25), ('production', 11), ('fine', 122), ('chemicals', 62), ('normal', 666), ('jinan', 296), ('p', 2806), ('r', 2506), ('china', 12313), ('cyzhang', 3), ('sdnu', 9), ('edu', 2574), ('cn', 1211), ('beijing', 1972), ('national', 3495), ('chinese', 2050), ('academy', 1854), ('multidisciplinary', 77), ('medical', 9787), ('surgical', 329), ('dental', 1085), ('specialties', 26), ('campania', 24), ('luigi', 39), ('vanvitelli', 25), ('naples', 144), ('italy', 1984), ('interdisciplinary', 214), ('medicine', 8402), ('bari', 114), ('aldo', 29), ('moro', 55), ('head', 366), ('neck', 356), ('fondazione', 58), ('policlinico', 76), ('universitario', 215), ('gemelli', 9), ('irccs', 123), ('università', 285), ('cattolica', 3), ('del', 187), ('sacro', 4), ('cuore', 4), ('rome', 227), ('compounding', 2), ('solutions', 8), ('israel', 354), ('eyal', 1), ('eyalzur', 2), ('pharm', 12), ('co', 285), ('il', 180), ('photochemical', 148), ('conversion', 151), ('optoelectronic', 224), ('technical', 285), ('physics', 1663), ('zhongguancun', 54), ('east', 492), ('road', 1522), ('haidian', 10), ('district', 192), ('lipzhang', 4), ('mail', 320), ('ipc', 37), ('yuxia', 4), ('zhao', 6), ('yuquan', 7), ('environmental', 325), ('shenzhen', 599), ('zhql', 2), ('szu', 13), ('indian', 135), ('technology', 4516), ('patna', 19), ('bihar', 12), ('india', 1041), ('biotechnology', 848), ('pharmaceutical', 2008), ('research', 5418), ('niper', 10), ('hajipur', 4), ('zhangwei', 2), ('tangb', 3), ('pharmacy', 1369), ('second', 374), ('military', 330), ('shanghai', 2841), ('people', 1164), ('republic', 2224), ('hebei', 86), ('north', 428), ('zhangjiakou', 6), ('obstetrics', 277), ('gynecology', 286), ('changzheng', 17), ('hospital', 9363), ('carbohydrate', 11), ('jiangnan', 45), ('wuxi', 84), ('energy', 360), ('south', 1199), ('agricultural', 121), ('guangzhou', 709), ('heliang', 1), ('scau', 1), ('j', 403), ('heyrovský', 9), ('physical', 426), ('czech', 335), ('dolejškova', 8), ('prague', 166), ('organic', 389), ('biochemistry', 911), ('flemingovo', 1), ('nám', 6), ('acadia', 63), ('wolfville', 63), ('nova', 101), ('scotia', 46), ('bp', 149), ('canada', 1008), ('carolin ...
nova': 81, 'bp': 147, 'carolina': 231, 'greensboro': 16, 'box': 451, 'radiology': 460, 'street': 845, 'usa': 4973, 'ny': 654, 'cornell': 89, 'innovations': 13, 'weill': 54, 'tianjin': 526, 'translational': 298, 'zheliu': 1, 'tju': 24, 'faculty': 2459, 'heliopolis': 2, 'cairo': 125, 'pharmaceutics': 328, 'drug': 608, 'egypt': 197, 'laser': 1414, 'applications': 191, 'niles': 16, 'lab': 347, 'first': 654, 'jilin': 277, 'gastrointestinal': 76, 'changchun': 450, 'pathology': ...
#
#  Vocabulary Size:
#  23830

# %%
wc=tk.word_counts
swc = pd.Series(wc)
df=pd.DataFrame({'Word':swc.index, 'Counts':swc.values})

# %%
print(df.head())
df=df.sort_values(by=['Counts'],ascending=False)
print(df.head())
# Out:
#          Word  Counts
# 0  department   25868
# 1   chemistry    6623
# 2  university   34715
# 3   rochester     318
# 4         new    1965
#            Word  Counts
# 2    university   34715
# 0    department   25868
# 108       china   12313
# 36    institute   10296
# 15       school   10289

# %%
import matplotlib.pyplot as plt

swc.plot.pie()

# %%
# export_csv = df.to_csv (os.path.join(base_dir2,'Tokenization_Results_PDT.csv'), index = None, header=True) #Don't forget to add '.csv' at the end of the path

# %% [markdown]
# # 2.2 - Research Area  - based on Web of Science

# %%
idx=np.where(pd.notnull(result.research_area))[0][:]
# s_ra=result.research_area[idx]
# s_ra
# export_series_csv=s_ra.to_csv(os.path.join(base_dir2,'WebOfScience_ResearchAreas.csv'),index=None, header=None)
#export_csv = df_pubmed.to_csv (os.path.join(base_dir2,'PubMed_DataFrame_papers.csv'), index = None, header=True) #Don't forget to add '.csv' at the end of the path
s_ra=result.groupby('research_area').count()
# export_series_csv=s_ra.pmid.to_csv(os.path.join(base_dir2,'WebOfScience_ResearchAreas.csv'), header=None)

# %% [markdown]
# # 2.3 Clustering Papers Part

# %%
if join:
  result['clean_abstract']=result['final_abstract'].apply(lambda x: clean_str(x))
  result.head()
else:
  df_pubmed['clean_abstract'] = df_pubmed['abstract_pubmed'].apply(lambda x: clean_str(x))
  df_wos['clean_abstract'] = df_wos['abstract_wos'].apply(lambda x: clean_str(x))
  print(df_pubmed.head())
  print('***')
  print(df_wos.head())
# Out:
#                                         title_pubmed  ...                                     clean_abstract
# 0  Excited State Torsional Processes in Chalcogen...  ...  chalcogenopyrylium monomethine cgpm dyes repre...
# 1  New strategies and developments for peri-impla...  ...  the aim of this illustrated review is to prese...
# 2  Comparison of apical periodontitis repair in e...  ...  this study evaluated the effect of antimicrobi...
# 3  Antimicrobial photodynamic therapy on teeth wi...  ...  molar incisor hypomineralization mih is a chan...
# 4  Evaluation of halitosis in adult patients afte...  ...  halitosis is an unpleasant odor that emanates ...
#
# [5 rows x 5 columns]
# ***
#        pmid  ...                                     clean_abstract
# 0  31500949  ...  transplant recipients have a significantly hig...
# 1  31543301  ...  although surgery and radiotherapy remain the m...
# 2  31355928  ...  background the objective of this study was to ...
# 3  31466584  ...  although surgical intervention remains the sta...
# 4  31555659  ...  fluorescence imaging is an emerging clinical t...
#
# [5 rows x 9 columns]

# %%
# Alterado Renan
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english", ignore_stopwords=False)
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf=TfidfVectorizer(max_features=200000,
                     max_df=0.9,
                     min_df=0.2,
                     stop_words='english',
                     ngram_range=(1,3))

def normalize_v2(x): 
  normalized = []
  words = nltk.word_tokenize(x)
  normalized.append(' '.join([stemmer.stem(word) for word in words if re.match('[a-zA-Z]+', word)]))
  return normalized


if join:
  text = []
  for row in result['clean_abstract'].values:
    text.append(normalize_v2(row)[0])
  result['clean_abstract']=text
else:
  text = []
  for row in df_pubmed['clean_abstract'].values:
    text.append(normalize_v2(row)[0])
  df_pubmed['clean_abstract']=text

  text = []
  for row in df_wos['clean_abstract'].values:
    text.append(normalize_v2(row)[0])
  df_wos['clean_abstract']=text

# %%
# from nltk.stem.snowball import SnowballStemmer
# stemmer = SnowballStemmer("english", ignore_stopwords=False)
# def normalize(X): 
#   normalized = []
#   for x in X:
#     words = nltk.word_tokenize(x)
#     normalized.append(' '.join([stemmer.stem(word) for word in words if re.match('[a-zA-Z]+', word)]))
#   return normalized

# %%
# from sklearn.pipeline import Pipeline
# from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
# from sklearn.preprocessing import FunctionTransformer

# pipe = Pipeline([
#   ('normalize', FunctionTransformer(normalize, validate=False)),
#   ('counter_vectorizer', CountVectorizer(
#     max_df=0.9, max_features=200000,
#     min_df=0.2, stop_words='english',
#     ngram_range=(1,5)
#   )),
#   ('tfidf_transform', TfidfTransformer())
# ])

# %%
# if join:
#   tfidf_matrix = pipe.fit_transform([x for x in result['clean_abstract']])
# else:
#   tfidf_matrix_pubmed = pipe.fit_transform([x for x in df_pubmed['clean_abstract']])
#   tfidf_matrix_wos = pipe.fit_transform([x for x in df_wos['clean_abstract']])

# %%
if join:
  tfidf_matrix = tfidf.fit_transform([x for x in result['clean_abstract']])
else:
  tfidf_matrix_pubmed = tfidf.fit_transform([x for x in df_pubmed['clean_abstract']])
  tfidf_matrix_wos = tfidf.fit_transform([x for x in df_wos['clean_abstract']])

# %%
if join:
  print('Merged PubMed and WoK TF-IDF matrix shape:',tfidf_matrix.get_shape())
else:
  print('PubMed TF-IDF matrix shape:',tfidf_matrix_pubmed.get_shape())
  print('WoK TF-IDF matrix shape:',tfidf_matrix_wos.get_shape())
# Out:
# PubMed TF-IDF matrix shape: (24268, 23)
# WoK TF-IDF matrix shape: (1274, 55)

# %%
from sklearn.metrics.pairwise import cosine_similarity 
if join:
  similarity_distance = 1 - cosine_similarity(tfidf_matrix)
else:
  similarity_distance_pubmed = 1 - cosine_similarity(tfidf_matrix_pubmed)
  similarity_distance_wos = 1 - cosine_similarity(tfidf_matrix_wos)

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram
if join:
  mergings = linkage(similarity_distance, method='complete')
  dendrogram_ = dendrogram(mergings,
                 labels=[x for x in result["final_title"]],
                 leaf_rotation=90,
                 leaf_font_size=16,
                )

  fig = plt.gcf()
  _ = [lbl.set_color('r') for lbl in plt.gca().get_xmajorticklabels()]
  fig.set_size_inches(108, 21)

  plt.show()
else:
  mergings = linkage(similarity_distance_pubmed, method='complete')
  dendrogram_ = dendrogram(mergings,
                 labels=[x for x in df_pubmed["title_pubmed"]],
                 leaf_rotation=90,
                 leaf_font_size=16,
                )

  fig = plt.gcf()
  _ = [lbl.set_color('r') for lbl in plt.gca().get_xmajorticklabels()]
  fig.set_size_inches(108, 21)

  plt.show()

  mergings = linkage(similarity_distance_wos, method='complete')
  dendrogram_ = dendrogram(mergings,
                 labels=[x for x in df_wos["title_wos"]],
                 leaf_rotation=90,
                 leaf_font_size=16,
                )

  fig = plt.gcf()
  _ = [lbl.set_color('r') for lbl in plt.gca().get_xmajorticklabels()]
  fig.set_size_inches(108, 21)

  plt.show()

# %%
if join:
  def find_similar(title):
    index = result[result['final_title'] == title].index[0]
    vector = similarity_distance[index, :]
    most_similar = result.iloc[np.argsort(vector)[1:20], 0].values
    return most_similar
else:
  def find_similar_pubmed(title):
    index = df_pubmed[df_pubmed['title_pubmed'] == title].index[0]
    vector = similarity_distance_pubmed[index, :]
    most_similar = df_pubmed.iloc[np.argsort(vector)[1:20], 0].values
    return most_similar
  def find_similar_wos(title):
    index = df_wos[df_wos['title_wos'] == title].index[0]
    vector = similarity_distance_wos[index, :]
    most_similar = df_wos.iloc[np.argsort(vector)[1:20], 2].values
    return most_similar

# %%
Title='meta-analysis'
if join:
  index_=result['final_title'].str.contains(Title)
  print(result.final_title[index_].values[:])
  print('Merged final indexes order:',np.where(index_)[0])

else:
  index_pubmed=df_pubmed['title_pubmed'].str.contains(Title)
  print('Pubmed Titles:\n',df_pubmed.title_pubmed[index_pubmed].values[:])
  print('Pubmed indexes order:',np.where(index_pubmed)[0])
  
  index_wos=df_wos['title_wos'].str.contains(Title)
  print('\nWeb of Science Titles:\n',df_wos.title_wos[index_wos].values[:])
  print('Web of Science indexes order:',np.where(index_wos)[0])
  #index_
# Out:
# ['Photodynamic therapy versus surgical excision to basal cell carcinoma:  meta-analysis'
#  'Photodynamic therapy in the treatment of basal cell carcinoma: a  systematic review and meta-analysis'
#  'Overall treatment success after treatment of primary superficial basal  cell carcinoma: a systematic review and meta-analysis of randomized and  nonrandomized trials'
#  'Surgical excision, Mohs micrographic surgery, external-beam  radiotherapy, or brachytherapy for indolent skin cancer: An  international meta-analysis of 58 studies with 21,000 patients'
#  'Surgical excision, Mohs micrographic surgery, external-beam  radiotherapy, or brachytherapy for indolent skin cancer: An  international meta-analysis of 58 studies with 21,000 patients'
#  'Efficacy and safety of imiquimod 5% cream for basal cell carcinoma: a  meta-analysis of randomized controlled trial'
#  'Conventional and combination topical photodynamic therapy for basal cell  carcinoma: systematic review and meta-analysis']
# Merged final indexes order: [ 81 139 223 682 683 891 921]

# %%
#export_csv = df_pubmed.to_csv (os.path.join(base_dir2,'PubMed_DataFrame_papers.csv'), index = None, header=True) #Don't forget to add '.csv' at the end of the path

# %%
if join:
  index_=81
  print('Base title:',result.final_title[index_]) # prints
  abst=(result.final_abstract[index_])
  if abst =='None':
    print('No Abstract available for this paper')
  else: 
    print('\nMost similar title:\n',find_similar(result.final_title[index_])) # prints  
else:
  index_pubmed=343
  print('Pubmed Base title:',df_pubmed.title_pubmed[index_pubmed]) # prints
  abst=(df_pubmed.abstract_pubmed[index_pubmed])
  if abst =='None':
    print('No Abstract available for this paper')
  else: 
    print('\n Pubmed database - Most similar title:\n',find_similar_pubmed(df_pubmed.title_pubmed[index_pubmed])) # prints 
  
  print('\n _____________________________________________________________________________________________________________________________________________________________________________________________________ \n')
  
  index_wos=740
  print('Web of ScienceBase title:',df_wos.title_wos[index_wos]) # prints 
  abst=(df_wos.abstract_wos[index_wos])
  if abst =='None':
    print('No Abstract available for this paper')
  else: 
    print('\n Web of Science database - Most similar title:\n',find_similar_wos(df_wos.title_wos[index_wos])) # prints
# Out:
# Base title: Photodynamic therapy versus surgical excision to basal cell carcinoma:  meta-analysis
#
# Most similar title:
#  ['Photodynamic Therapy Followed by Mohs Micrographic Surgery Compared to Mohs Micrographic Surgery Alone for the Treatment of Basal Cell Carcinoma: Results of a Pilot Single-Blinded Randomised Controlled Trial.'
#  'PDT in squamous cell carcinoma of the skin.'
#  'Topical photodynamic therapy significantly reduces epidermal Langerhans cells during clinical treatment of basal cell carcinoma.'
#  'Comprehensive analysis of alterations in the miRNome in response to photodynamic treatment.'
#  'Pre-treatment deep curettage can significantly reduce tumour thickness in thick Basal cell carcinoma while maintaining a favourable cosmetic outcome when used in combination with topical photodynamic therapy.'
#  'Daylight-mediated photodynamic therapy in Spain: advantages and disadvantages.'
#  'Therapeutic effect of Imiquimod enhanced ALA-PDT on cutaneous squamous cell carcinoma.'
#  'Photodynamic therapy and pain: A systematic review.'
#  'Daylight Photodynamic Therapy for Actinic Keratoses.'
#  'Er:YAG ablative fractional laser-primed photodynamic therapy with methyl aminolevulinate as an alternative treatment option for patients with thin nodular basal cell carcinoma: 12-month follow-up results of a randomized, prospective, comparative trial.'
#  'Photodynamic therapy in the management of basal cell carcinoma: Retrospective evaluation of outcome.'
#  'Curettage and multiple needle puncture-assisted methyl-aminolaevulinate photodynamic therapy of basal cell carcinoma.'
#  'Methylaminolaevulinate photodynamic therapy in patients with multiple basal cell carcinomas in the setting of Gorlin-Goltz syndrome or after radiotherapy.'
#  'Comparative study between cold air analgesia and supraorbital and supratrochlear nerve block for the management of pain during photodynamic therapy for actinic keratoses of the frontotemporal zone.'
#  nan
#  'Is a single day patient friendly methyl aminolevulinate photodynamic therapy illumination scheme for superficial basal cell carcinoma feasible? A randomized multicenter pilot trial.'
#  'Risk of acute postoperative hypertension after topical photodynamic therapy for non-melanoma skin cancer.'
#  'Combined CO(2) laser with photodynamic therapy for the treatment of nodular basal cell carcinomas.'
#  'Spotlighting the role of photodynamic therapy in cutaneous malignancy: an update and expansion.']
